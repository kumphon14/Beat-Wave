# %% [markdown]
# # <font color="#FFA500">Beat Frequency</font>
# หากพูดถึง **บีตส์ (beat)** หลายๆ คนโดยทั่วไปมักจะนึกถึง **จังหวะ** เพลงของดนตรี หรือแม้กระทั่งคนที่เคยเล่นดนตรี หรือเป็นนักดนตรีอยู่แล้ว ก็มักจะคุ้นเคยกับคำคำนี้
#
# ตัวผมเองก็ผ่านการเล่นกีต้าร์มา 🎸
# ในช่วงที่หัดเล่นใหม่ๆ ก็ต้องมีการปรับสายกีต้าร์ก่อนเล่น
# วิธีที่ง่ายที่สุดในยุคสมัยนี้คือ **App Tuning Guitar** ซึ่งมีความสะดวกสบาย
#
# 🫤❓ แต่ก็อดสงสัยไม่ได้ว่า...
# - ถ้าเราไม่มี **App Tuning Guitar** เราจะปรับสายกีต้าร์อย่างไร?
# - แล้วคนสมัยก่อนที่ยังไม่มีโทรศัพท์ เขาปรับสายกีต้าร์กันอย่างไร?
#
# ผมได้ไปหาคำตอบมาแล้ว! หากใครที่เป็นมือใหม่เพิ่งเริ่มเล่นกีต้าร์ และอยากรู้ที่มาของปรากฏการณ์ **บีตส์ของเสียง (beat)** ว่าเกี่ยวข้องกับการปรับสายกีต้าร์อย่างไร สามารถกดดู **ลิงก์นี้** ได้เลยครับ:
# [https://www.youtube.com/watch?v=1UTjWy-vnOo&ab_channel=MarkRober](https://www.youtube.com/watch?v=1UTjWy-vnOo&ab_channel=MarkRober)
#
#
# ### <font color="#FFA500">เราทำความเข้าใจเรื่องการซ้อนทับกันของคลื่นก่อน 🔊</font>
# เมื่อคลื่นเสียงจาดแหล่งกำเนิด 2 แหล่งเคลื่อนที่ไปพบกันจะทำให้เกิดการรวมกันของคลื่นซึ่งมีสองลักษณะดังนี้
#  - Constructive Interference คือ ตำแหน่งที่คลื่นรวมกันแบบเสริมกันเรียกว่าปฏิบัพ ( Antinode ) ซึ่งตำแหน่งนี้เสียงจะ **ดัง**
#  - Destructive Interference คือ ตำแหน่งที่คลื่นรวมกันแบบหักล้างเรียกว่าบัพ (Node) ซึ่งตำแหน่งนี้เสียงจะ **เบา**
#
# <div style="text-align: center;">
# <img src ="https://science8sc.weebly.com/uploads/1/3/2/7/132773018/constructive-interference-gif_orig.gif" alt="Constructive Interference" width="200">
# <img src ="https://science8sc.weebly.com/uploads/1/3/2/7/132773018/destructive-interference-gif_orig.gif" alt="Destructive Interference" width="200">
# </div>

# %% [markdown]
# ### <font color="#BBB500">ความถี่ (Beat Frequency) คือ ?</font>
# > "คือการที่ Amplitude ของคลื่นรวมมีการเปลี่ยนแปลงเป็นคาบ ณ จุดสังเกตจุดหนึ่งเนื่องจากการซ้อนทับกัยของคลื่นสองคลื่นที่มีความถี่ต่างกันเล็กน้อย" <br>
# > (🤔🤔🤔ฟังแล้วดูงงๆ กันจะแปลเป็นภาษาง่ายๆ)

# %% [markdown]
# > "การที่มีแหล่งกำเนิดคลื่นเสียง 2 ขบวนที่มี <font color="#FFC0CB">ความถี่ต่างกันเล็กน้อย</font> เดินทางมาเจอกันแล้วทำให้เกิดเสียงดัง-เบา สลับกันไปเป็นจังหวะ"
#
# <div style="text-align: center;">
# <img src ="https://www.physics-and-radio-electronics.com/physics/images/beats.png" alt="img" width="500">
# </div>
#
# - หากจะคำนวณหาความถี่บีสต์(Beat Frequency : $f_{B}$) ว่าเราสามารถได้ยินจังหวะบีตส์ได้กี่ครั้งต่อวินาที จากสูตร
# $$
# f_{B} = \lvert f_{1} - f_{2} \rvert
# $$ <br>
#
# - หากต้องการคำนวณหาค่าเฉลี่ยของความถี่บีตส์ที่เราได้ยินว่าเป็นเสียงบีตส์สูง หรือบีตส์ต่ำ บางทีอาจเรียกว่า (Effective Frequency : $f_{eff}$) จากสูตร
# $$
# f_{eff} = \frac{f_{1} + f_{2}}{2}
# $$

# %% [markdown]
# ### <font color="red">🎺 ที่มาของสูตรการคำนวณ</font>
# จากสมการทั่วไปของคลื่น
# $$ y = A\sin(kx-\omega t + \phi) $$
#
# พิจารณาการเคลื่อนที่ของคลื่นที่มี **Amplitude** $(A)$ เท่ากันแต่มีความถี่ต่างกันเล็กน้อย $ f_{1} $ และ $ f_{2} $ ที่ตำแหน่ง $ x = 0 $ และมุมเฟสเริ่ม
# $ \phi = \pi/2 $
#
# $$
# y_1 = A \sin\left(\frac{\pi}{2} - \omega_1 t\right) = A \cos\left(2\pi f_1 t\right)
# $$
#
# $$
# y_2 = A \sin\left(\frac{\pi}{2} - \omega_2 t\right) = A \cos\left(2\pi f_2 t\right)
# $$
#
# <div style="text-align: center;">
#   <img src="Src/wave.png" alt="wave" width="700">
# </div>
#
# 🌊 **จากหลักการซ้อนทับของคลื่น** คือการนำคลื่น 2 ขบวนมารวมกันดังนี้
#
# $$
# y = y_1 + y_2 = A \left(\cos 2\pi f_1 t + \cos 2\pi f_2 t\right)
# $$
#
# จากเอกลักษณ์ตรีโกณมิติ:
#
# $$
# \cos a + \cos b = 2 \cos\left(\frac{a-b}{2}\right) \cos\left(\frac{a+b}{2}\right)
# $$
#
# ดังนั้นเราจะได้สมการดังนี้:
#
# $$
# y = 2A\left[\cos 2\pi \left(\frac{f_1 - f_2}{2}\right) t \right] \left[\cos 2\pi \left(\frac{f_1 + f_2}{2}\right) t \right]
# $$
#
# <div style="text-align: center;">
#   <img src="Src/BeatWaveimg.png" alt="wave" width="700">
# </div>
#
# 📈 จากสมการพบว่าในส่วนของ $ (f_{1} + f_{2})/2 $ คือ Effective Frequency : $f_{eff}$ และ
#
# $$
# y = 2A \cos 2\pi \left(\frac{f_1 - f_2}{2}\right)t
# $$
#
# **Amplitude** หรือความเข้มเสียงของคลื่นที่รวมกันแล้วนั้นมีการเปลี่ยนแปลงขึ้นกับเวลา $ (f_{1} - f_{2}) /2 $
# ดังนั้น Amplitude สูงสุดหรือเสียงที่ดังที่สุดจะเกิดเมื่อ:
#
# $$
# \cos 2\pi \left(\frac{f_1 - f_2}{2}\right)t = \pm 1
# $$
#
# **ความถี่บีตส์ (Beat Frequency : $ f_{B}$ )** มีค่าเป็นสองเท่าของค่านี้ นั่นคือ:
#
# $$
# f_\text{B} = \lvert f_1 - f_2 \rvert
# $$
